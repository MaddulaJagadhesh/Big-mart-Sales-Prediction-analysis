# %% [markdown]
# ## Big Mart Sales Prediction Analysis using Machine Learning

# %% [markdown]
# The data scientists at BigMart have collected 2013 sales data for 1559 products across 10 stores in different cities. Also, certain attributes of each product and store have been defined. The aim is to build a predictive model and find out the sales of each product at a particular store.
#
# Using this model, BigMart will try to understand the properties of products and stores which play a key role in increasing sales.
#
#
# Variable | Description
# ----------|--------------
# Item_Identifier | Unique product ID
# Item_Weight | Weight of product
# Item_Fat_Content | Whether the product is low fat or not
# Item_Visibility | The % of total display area of all products in a    store allocated to the particular product
# Item_Type | The category to which the product belongs
# Item_MRP | Maximum Retail Price (list price) of the product
# Outlet_Identifier | Unique store ID
# Outlet_Establishment_Year | The year in which store was established
# Outlet_Size | The size of the store in terms of ground area covered
# Outlet_Location_Type | The type of city in which the store is located
# Outlet_Type | Whether the outlet is just a grocery store or some sort of supermarket
# Item_Outlet_Sales | Sales of the product in the particulat store. This is the outcome variable to be predicted.

# %% [markdown]
# ### Sales data for 1559 products across 10 stores in different cities

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
# %matplotlib inline
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('Train.csv')
df.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50          Low Fat         0.016760
# 3           FDX07        19.20          Regular         0.000000
# 4           NCD19         8.93          Low Fat         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# ...

# %%
df.shape
# Out:
# (8523, 12)

# %%
df.hist(figsize=(15,12))
# Out:
# array([[<AxesSubplot:title={'center':'Item_Weight'}>,
#         <AxesSubplot:title={'center':'Item_Visibility'}>],
#        [<AxesSubplot:title={'center':'Item_MRP'}>,
#         <AxesSubplot:title={'center':'Outlet_Establishment_Year'}>],
#        [<AxesSubplot:title={'center':'Item_Outlet_Sales'}>,
#         <AxesSubplot:>]], dtype=object)

# %%
# statistical info
df.describe()
# Out:
#        Item_Weight  Item_Visibility     Item_MRP  Outlet_Establishment_Year  \
# count  7060.000000      8523.000000  8523.000000                8523.000000
# mean     12.857645         0.066132   140.992782                1997.831867
# std       4.643456         0.051598    62.275067                   8.371760
# min       4.555000         0.000000    31.290000                1985.000000
# 25%       8.773750         0.026989    93.826500                1987.000000
# 50%      12.600000         0.053931   143.012800                1999.000000
# 75%      16.850000         0.094585   185.643700                2004.000000
# max      21.350000         0.328391   266.888400                2009.000000
#
#        Item_Outlet_Sales
# count        8523.000000
# mean         2181.288914
# std          1706.499616
# min            33.290000
# 25%           834.247400
# 50%          1794.331000
# 75%          3101.296400
# max         13086.964800

# %%
# datatype of attributes
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8523 entries, 0 to 8522
# Data columns (total 12 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Item_Identifier            8523 non-null   object
#  1   Item_Weight                7060 non-null   float64
#  2   Item_Fat_Content           8523 non-null   object
#  3   Item_Visibility            8523 non-null   float64
#  4   Item_Type                  8523 non-null   object
#  5   Item_MRP                   8523 non-null   float64
#  6   Outlet_Identifier          8523 non-null   object
#  7   Outlet_Establishment_Year  8523 non-null   int64
#  8   Outlet_Size                6113 non-null   object
#  9   Outlet_Location_Type       8523 non-null   object
#  10  Outlet_Type                8523 non-null   object
#  11  Item_Outlet_Sales          8523 non-null   float64
# dtypes: float64(4), int64(1), object(7)
# memory usage: 799.2+ KB

# %%
# check for duplicated rows
df.duplicated().any()
# Out:
# False

# %%
df.plot(kind='box', subplots=True, layout=(1,5), figsize=(20,5))
# Out:
# Item_Weight                     AxesSubplot(0.125,0.125;0.133621x0.755)
# Item_Visibility              AxesSubplot(0.285345,0.125;0.133621x0.755)
# Item_MRP                      AxesSubplot(0.44569,0.125;0.133621x0.755)
# Outlet_Establishment_Year    AxesSubplot(0.606034,0.125;0.133621x0.755)
# Item_Outlet_Sales            AxesSubplot(0.766379,0.125;0.133621x0.755)
# dtype: object

# %% [markdown]
# In ITEM OUTLET SALES the outliers can remain there as in some season the sales jump abruptly.

# %%
# check unique values in dataset
df.apply(lambda x: len(x.unique()))
# Out:
# Item_Identifier              1559
# Item_Weight                   416
# Item_Fat_Content                5
# Item_Visibility              7880
# Item_Type                      16
# Item_MRP                     5938
# Outlet_Identifier              10
# Outlet_Establishment_Year       9
# Outlet_Size                     4
# Outlet_Location_Type            3
# Outlet_Type                     4
# Item_Outlet_Sales            3493
# dtype: int64

# %% [markdown]
# ### Preprocessing the Dataset

# %%
# check for null values
df.isnull().sum()
# Out:
# Item_Identifier                 0
# Item_Weight                  1463
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  2410
# Outlet_Location_Type            0
# Outlet_Type                     0
# Item_Outlet_Sales               0
# dtype: int64

# %% [markdown]
# ITEM WEIGHT and OUTLET SIZE contains null values.

# %%
# check for categorical attributes
cat_col = []
for x in df.dtypes.index:
    if df.dtypes[x] == 'object':
        cat_col.append(x)
cat_col
# Out:
# ['Item_Identifier',
#  'Item_Fat_Content',
#  'Item_Type',
#  'Outlet_Identifier',
#  'Outlet_Size',
#  'Outlet_Location_Type',
#  'Outlet_Type']

# %%
cat_col.remove('Item_Identifier')
cat_col.remove('Outlet_Identifier')
cat_col
# Out:
# ['Item_Fat_Content',
#  'Item_Type',
#  'Outlet_Size',
#  'Outlet_Location_Type',
#  'Outlet_Type']

# %%
# print the categorical columns
for col in cat_col:
    print(col)
    print(df[col].value_counts())
    print()
# Out:
# Item_Fat_Content
# Low Fat    5089
# Regular    2889
# LF          316
# reg         117
# low fat     112
# Name: Item_Fat_Content, dtype: int64
#
# Item_Type
# Fruits and Vegetables    1232
# Snack Foods              1200
# Household                 910
# Frozen Foods              856
# Dairy                     682
# Canned                    649
# Baking Goods              648
# Health and Hygiene        520
# Soft Drinks               445
# Meat                      425
# Breads                    251
# Hard Drinks               214
# Others                    169
# Starchy Foods             148
# Breakfast                 110
# Seafood                    64
# Name: Item_Type, dtype: int64
#
# Outlet_Size
# Medium    2793
# Small     2388
# High       932
# Name: Outlet_Size, dtype: int64
#
# Outlet_Location_Type
# Tier 3    3350
# Tier 2    2785
# Tier 1    2388
# Name: Outlet_Location_Type, dtype: int64
#
# Outlet_Type
# Supermarket Type1    5577
# Grocery Store        1083
# ...

# %% [markdown]
# ### Notes:
# 1) The dataset 8523 contains datapoints (rows) and 12 features (columns).<br>
# 2) The dataset is for 1559 items in 10 different stores.<br>
# 3) There are both categorical (object) and numerical features (float, int).<br>
# 4) The target is the _'Item_OutletSales' feature.<br>
# 5) Some features contains null values and outliers.<br>
# 6) There are no duplicate rows.<br>
#
#
# ### _ItemIdentifier:.
#
# 1) Ids for 1559 different items.<br>
# 2) The ids has some prefixes: FD=Food, DR=Drink, NC=Non-Consumable.<br>
# ### _ItemWeight:
#
# It contains null values.<br>
# ### _Item_FatContent:
#
# 1) It has 5 different categories, but some of them do reference to an existing category, it can be summarized to two categories: Low Fat and Regular.<br>
# 2) This feature do not apply to Non-Consumable items, a new category for them can be created.<br>
# ### _ItemVisibility:
#
# 1) Some values are 0%, an item can not be bought by a consumer if its not visible, this is an outlier.<br>
# ### _ItemType:
#
# 1) There are 16 different item types, the data is not well distributed among all of them.<br>
# 2) The model can be biased towards the most repetitive types: Fruits and Vegetables and Snack Foods.<br>
# ### _OutletIdentifier:
#
# 1) There are 10 different outlet ids.<br>
# 2) The data seems to be pretty well distributed among all the outlets.<br>
# ### _OutletSize:
#
# 1) It has null values.<br>
# 2) The data is not well distributed among the different sizes.<br>
# 3) The _OuletSize has some relation with the _OuletType that need to be considered when the null values be filled.<br>
# ### _Outlet_Location_Type and OutletType:
#
# 1) The data is not well distributed among the different sizes.<br>
# 2) The model can be biased towards the most repetitive types.<br>

# %%
# fill the missing values
item_weight_mean = df.pivot_table(values = "Item_Weight", index = 'Item_Identifier')
item_weight_mean
# Out:
#                  Item_Weight
# Item_Identifier
# DRA12                 11.600
# DRA24                 19.350
# DRA59                  8.270
# DRB01                  7.390
# DRB13                  6.115
# ...                      ...
# NCZ30                  6.590
# NCZ41                 19.850
# NCZ42                 10.500
# NCZ53                  9.600
# NCZ54                 14.650
#
# [1555 rows x 1 columns]

# %%
miss_bool = df['Item_Weight'].isnull()
miss_bool
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 8518    False
# 8519    False
# 8520    False
# 8521    False
# 8522    False
# Name: Item_Weight, Length: 8523, dtype: bool

# %%
for i, item in enumerate(df['Item_Identifier']):
    if miss_bool[i]:
        if item in item_weight_mean:
            df['Item_Weight'][i] = item_weight_mean.loc[item]['Item_Weight']
        else:
            df['Item_Weight'][i] = np.mean(df['Item_Weight'])

# %%
df['Item_Weight'].isnull().sum()
# Out:
# 0

# %%
outlet_size_mode = df.pivot_table(values='Outlet_Size', columns='Outlet_Type', aggfunc=(lambda x: x.mode()[0]))
outlet_size_mode
# Out:
# Outlet_Type Grocery Store Supermarket Type1 Supermarket Type2  \
# Outlet_Size         Small             Small            Medium
#
# Outlet_Type Supermarket Type3
# Outlet_Size            Medium

# %%
miss_bool = df['Outlet_Size'].isnull()
df.loc[miss_bool, 'Outlet_Size'] = df.loc[miss_bool, 'Outlet_Type'].apply(lambda x: outlet_size_mode[x])

# %%
df['Outlet_Size'].isnull().sum()
# Out:
# 0

# %%
sum(df['Item_Visibility']==0)
# Out:
# 526

# %%
# replace zeros with mean
df.loc[:, 'Item_Visibility'].replace([0], [df['Item_Visibility'].mean()], inplace=True)

# %%
sum(df['Item_Visibility']==0)
# Out:
# 0

# %%
# combine item fat content
df['Item_Fat_Content'] = df['Item_Fat_Content'].replace({'LF':'Low Fat', 'reg':'Regular', 'low fat':'Low Fat'})
df['Item_Fat_Content'].value_counts()
# Out:
# Low Fat    5517
# Regular    3006
# Name: Item_Fat_Content, dtype: int64

# %%
df['New_Item_Type'] = df['Item_Identifier'].apply(lambda x: x[:2])
df['New_Item_Type']
# Out:
# 0       FD
# 1       DR
# 2       FD
# 3       FD
# 4       NC
#         ..
# 8518    FD
# 8519    FD
# 8520    NC
# 8521    FD
# 8522    DR
# Name: New_Item_Type, Length: 8523, dtype: object

# %%
df['New_Item_Type'] = df['New_Item_Type'].map({'FD':'Food', 'NC':'Non-Consumable', 'DR':'Drinks'})
df['New_Item_Type'].value_counts()
# Out:
# Food              6125
# Non-Consumable    1599
# Drinks             799
# Name: New_Item_Type, dtype: int64

# %%
df.loc[df['New_Item_Type']=='Non-Consumable', 'Item_Fat_Content'] = 'Non-Edible'
df['Item_Fat_Content'].value_counts()
# Out:
# Low Fat       3918
# Regular       3006
# Non-Edible    1599
# Name: Item_Fat_Content, dtype: int64

# %%
# create small values for establishment year
df['Outlet_Years'] = 2013 - df['Outlet_Establishment_Year']

# %%
df['Outlet_Years']
# Out:
# 0       14
# 1        4
# 2       14
# 3       15
# 4       26
#         ..
# 8518    26
# 8519    11
# 8520     9
# 8521     4
# 8522    16
# Name: Outlet_Years, Length: 8523, dtype: int64

# %%
df.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50          Low Fat         0.016760
# 3           FDX07        19.20          Regular         0.066132
# 4           NCD19         8.93       Non-Edible         0.066132
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# ...

# %% [markdown]
# ## Analyze and visualize the data(EDA)

# %% [markdown]
# ### Univariate Analysis

# %%
df.plot(kind='hist', subplots=True, layout=(1,6), figsize=(20,5))
# Out:
# array([[<AxesSubplot:ylabel='Frequency'>,
#         <AxesSubplot:ylabel='Frequency'>,
#         <AxesSubplot:ylabel='Frequency'>,
#         <AxesSubplot:ylabel='Frequency'>,
#         <AxesSubplot:ylabel='Frequency'>,
#         <AxesSubplot:ylabel='Frequency'>]], dtype=object)

# %% [markdown]
# ITEM VISIBLITY, ITEM MRP and OUTLET ESTABLISHMENT YEAR are having similar data in the dataset. While ITEM OUTLET SALES is hvaing some very high values like 10000, which can happen. As during some festival seasons the sales can increase exponentially. So, we won't drop those high values nor would impute them.

# %%
sns.distplot(df['Item_Weight'])
# Out:
# <AxesSubplot:xlabel='Item_Weight', ylabel='Density'>

# %%
sns.distplot(df['Item_Visibility'])
# Out:
# <AxesSubplot:xlabel='Item_Visibility', ylabel='Density'>

# %%
sns.distplot(df['Item_MRP'])
# Out:
# <AxesSubplot:xlabel='Item_MRP', ylabel='Density'>

# %%
sns.distplot(df['Item_Outlet_Sales'])
# Out:
# <AxesSubplot:xlabel='Item_Outlet_Sales', ylabel='Density'>

# %%
# log transformation
df['Item_Outlet_Sales'] = np.log(1+df['Item_Outlet_Sales'])

# %%
sns.distplot(df['Item_Outlet_Sales'])
# Out:
# <AxesSubplot:xlabel='Item_Outlet_Sales', ylabel='Density'>

# %%
sns.countplot(df["Item_Fat_Content"])
# Out:
# <AxesSubplot:xlabel='Item_Fat_Content', ylabel='count'>

# %%
l = list(df['Item_Type'].unique())
chart = sns.countplot(df["Item_Type"])
chart.set_xticklabels(labels=l, rotation=90)
# Out:
# [Text(0, 0, 'Dairy'),
#  Text(1, 0, 'Soft Drinks'),
#  Text(2, 0, 'Meat'),
#  Text(3, 0, 'Fruits and Vegetables'),
#  Text(4, 0, 'Household'),
#  Text(5, 0, 'Baking Goods'),
#  Text(6, 0, 'Snack Foods'),
#  Text(7, 0, 'Frozen Foods'),
#  Text(8, 0, 'Breakfast'),
#  Text(9, 0, 'Health and Hygiene'),
#  Text(10, 0, 'Hard Drinks'),
#  Text(11, 0, 'Canned'),
#  Text(12, 0, 'Breads'),
#  Text(13, 0, 'Starchy Foods'),
#  Text(14, 0, 'Others'),
#  Text(15, 0, 'Seafood')]

# %%
sns.countplot(df['Outlet_Establishment_Year'])
# Out:
# <AxesSubplot:xlabel='Outlet_Establishment_Year', ylabel='count'>

# %%
sns.countplot(df['Outlet_Size'])
# Out:
# <AxesSubplot:xlabel='Outlet_Size', ylabel='count'>

# %%
sns.countplot(df['Outlet_Location_Type'])
# Out:
# <AxesSubplot:xlabel='Outlet_Location_Type', ylabel='count'>

# %%
sns.countplot(df['Outlet_Type'])
# Out:
# <AxesSubplot:xlabel='Outlet_Type', ylabel='count'>

# %%
df.hist(figsize=(12,8))
# Out:
# array([[<AxesSubplot:title={'center':'Item_Weight'}>,
#         <AxesSubplot:title={'center':'Item_Visibility'}>],
#        [<AxesSubplot:title={'center':'Item_MRP'}>,
#         <AxesSubplot:title={'center':'Outlet_Establishment_Year'}>],
#        [<AxesSubplot:title={'center':'Item_Outlet_Sales'}>,
#         <AxesSubplot:title={'center':'Outlet_Years'}>]], dtype=object)

# %% [markdown]
# ### Bivariate analysis

# %%
plt.figure(figsize=(10,6))
sns.barplot(x=df['Outlet_Identifier'], y=df['Item_Outlet_Sales'])
df['Outlet_Identifier'].value_counts()
# Out:
# OUT027    935
# OUT013    932
# OUT049    930
# OUT046    930
# OUT035    930
# OUT045    929
# OUT018    928
# OUT017    926
# OUT010    555
# OUT019    528
# Name: Outlet_Identifier, dtype: int64

# %% [markdown]
# ### Coorelation Matrix

# %%
df.corr()
# Out:
#                            Item_Weight  Item_Visibility  Item_MRP  \
# Item_Weight                   1.000000        -0.017450  0.024756
# Item_Visibility              -0.017450         1.000000 -0.005259
# Item_MRP                      0.024756        -0.005259  1.000000
# Outlet_Establishment_Year    -0.008301        -0.078355  0.005020
# Item_Outlet_Sales             0.008059        -0.202466  0.509886
# Outlet_Years                  0.008301         0.078355 -0.005020
#
#                            Outlet_Establishment_Year  Item_Outlet_Sales  \
# Item_Weight                                -0.008301           0.008059
# Item_Visibility                            -0.078355          -0.202466
# Item_MRP                                    0.005020           0.509886
# Outlet_Establishment_Year                   1.000000           0.077032
# Item_Outlet_Sales                           0.077032           1.000000
# ...

# %%
corr = df.corr()
sns.heatmap(corr, annot=True,cmap='coolwarm')
# Out:
# <AxesSubplot:>

# %% [markdown]
# We can see that none of the Input features is having high correlation factor (> 0.6) with the Output features.

# %%
# scatter plot of item_mrp and item_outlet_sales
sns.scatterplot(data=df, x='Item_MRP', y='Item_Outlet_Sales')
# Out:
# <AxesSubplot:xlabel='Item_MRP', ylabel='Item_Outlet_Sales'>

# %% [markdown]
# ### Notes:
# - The data present some minor changes based on what was done in the previous step.<br>
# - Some of the categorical features are not well distributed, the model can present some bias toward the most repetitive ones.<br>
# - There is not a clear correlation with the numerical features, _'itemmrp' seems to be the most essential feature to estimate the _'item_outletsales'.

# %%
sns.barplot(x=df['Item_Identifier'], y=df['Item_Outlet_Sales'])
df['Item_Identifier'].value_counts()
# Out:
# FDW13    10
# FDG33    10
# NCY18     9
# FDD38     9
# DRE49     9
#          ..
# FDY43     1
# FDQ60     1
# FDO33     1
# DRF48     1
# FDC23     1
# Name: Item_Identifier, Length: 1559, dtype: int64

# %% [markdown]
# So, we can see that the ITEM IDENTIFIER is not of so much importance wrt to Output feature

# %% [markdown]
# ### Multivariate Analysis

# %%
sns.pairplot(df)

# %% [markdown]
# ## Label Encoding

# %%
=
